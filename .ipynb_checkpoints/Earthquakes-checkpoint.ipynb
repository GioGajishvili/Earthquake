# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# Load the data

file_path = 'Earthquakes_database.csv'
earthquakes = pd.read_csv(file_path, parse_dates=['Date'], infer_datetime_format=True)
earthquakes.head()
# Out:
#                   Date      Time  Latitude  Longitude        Type  Depth  \
# 0  1965-01-02 00:00:00  13:44:18    19.246    145.616  Earthquake  131.6
# 1  1965-01-04 00:00:00  11:29:49     1.863    127.352  Earthquake   80.0
# 2  1965-01-05 00:00:00  18:05:58   -20.579   -173.972  Earthquake   20.0
# 3  1965-01-08 00:00:00  18:49:43   -59.076    -23.557  Earthquake   15.0
# 4  1965-01-09 00:00:00  13:32:50    11.938    126.427  Earthquake   15.0
#
#    Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0          NaN                     NaN        6.0             MW  ...
# 1          NaN                     NaN        5.8             MW  ...
# 2          NaN                     NaN        6.2             MW  ...
# 3          NaN                     NaN        5.8             MW  ...
# 4          NaN                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# ...

# %%
# გასუფთავება სპლიტი


earthquakes_df['Date'] = pd.to_datetime(earthquakes_df['Date'], errors='coerce', utc=True)
earthquakes_df['Year'] = earthquakes_df['Date'].dt.year
earthquakes_df['Month'] = earthquakes_df['Date'].dt.month
earthquakes_df['Day'] = earthquakes_df['Date'].dt.day
columns_to_drop = ['Depth Error', 'Depth Seismic Stations', 'Magnitude Type', 'Magnitude Error', 'Root Mean Square', 'Azimuthal Gap','Magnitude Seismic Stations', 'Horizontal Distance', 'Horizontal Error']
cleaned = earthquakes_df.drop(columns=columns_to_drop)
cleaned.head()
# Out:
#                        Date      Time  Latitude  Longitude        Type  Depth  \
# 0 1965-01-02 00:00:00+00:00  13:44:18    19.246    145.616  Earthquake  131.6
# 1 1965-01-04 00:00:00+00:00  11:29:49     1.863    127.352  Earthquake   80.0
# 2 1965-01-05 00:00:00+00:00  18:05:58   -20.579   -173.972  Earthquake   20.0
# 3 1965-01-08 00:00:00+00:00  18:49:43   -59.076    -23.557  Earthquake   15.0
# 4 1965-01-09 00:00:00+00:00  13:32:50    11.938    126.427  Earthquake   15.0
#
#    Magnitude            ID  Source Location Source Magnitude Source  \
# 0        6.0  ISCGEM860706  ISCGEM          ISCGEM           ISCGEM
# 1        5.8  ISCGEM860737  ISCGEM          ISCGEM           ISCGEM
# 2        6.2  ISCGEM860762  ISCGEM          ISCGEM           ISCGEM
# 3        5.8  ISCGEM860856  ISCGEM          ISCGEM           ISCGEM
# 4        5.8  ISCGEM860890  ISCGEM          ISCGEM           ISCGEM
#
#       Status  Year  Month  Day
# 0  Automatic  1965      1    2
# ...

# %%
# კატეგორიის სვეტის დამატება


magnitude_bins = [0, 4, 6, 10]
magnitude_labels = ['Low', 'Medium', 'High']

df['Magnitude Category'] = pd.cut(df['Magnitude'], bins=magnitude_bins, labels=magnitude_labels)

df.head()
# Out:
#        Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  1/2/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  1/4/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  1/5/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  1/8/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  1/9/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  Azimuthal Gap  \
# 0                     NaN        6.0             MW  ...            NaN
# 1                     NaN        5.8             MW  ...            NaN
# 2                     NaN        6.2             MW  ...            NaN
# 3                     NaN        5.8             MW  ...            NaN
# 4                     NaN        5.8             MW  ...            NaN
#
#    Horizontal Distance  Horizontal Error  Root Mean Square            ID  \
# ...

# %%
dataframe1_df = earthquakes_df_cleaned.melt(id_vars=['Day', 'Date',  'Month', 'Year'], value_vars=['Magnitude', 'Depth'], var_name='Measurement', value_name='Value')
dataframe1_df.head()


pivot_table_df = earthquakes_df_cleaned.pivot_table(values='Magnitude', index='Year', columns='Type', aggfunc='mean')
pivot_table_df.head()
# Out:
# Type  Earthquake  Explosion  Nuclear Explosion  Rock Burst
# Year
# 1965    6.014159        NaN                NaN         NaN
# 1966    6.042275        NaN              5.620         NaN
# 1967    6.003922        NaN                NaN         NaN
# 1968    6.081848        NaN              5.575         NaN
# 1969    6.009938        NaN              5.820         NaN

# %%
# ვიზუალიზაცია


plt.figure(figsize=(10,6))
pivot_table_df.plot(kind='line', legend=True)
plt.title('საშუალო სიდიდე წელიწადში ტიპების მიხედვით')
plt.xlabel('წელი')
plt.ylabel('საშუალო მაგნიტუდა')
plt.legend(title='ტიპები')
plt.show()

# Earthquake Count by Magnitude Category
plt.figure(figsize=(10,6))
sns.barplot(x='Magnitude Category', y='count', data=earthquakes_df_cleaned['Magnitude Category'].value_counts().reset_index().rename(columns={'index': 'Magnitude Category', 'Magnitude Category': 'count'}))
plt.title('მიწისძვრების რაოდენობა კატეგორიების მიხედვით')
plt.xlabel('მაგნიტუდის კატეგორია')
plt.ylabel('მიწისძვრების რაოდენობა')
plt.show()

# Depth vs Magnitude
plt.figure(figsize=(10,6))
sns.scatterplot(x='Magnitude', y='Depth', hue='Magnitude Category', data=earthquakes_df_cleaned, palette='viridis')
plt.title('მაგნიტუდა vs სიღრმე')
plt.xlabel('მაგნიტუდა')
plt.ylabel('სიღრმე (km)')
plt.legend(title='მაგნიტუდის კატეგორია')
plt.show()

# Distribution of Earthquake Depths
plt.figure(figsize=(10,6))
sns.histplot(data=earthquakes_df_cleaned, x='Depth', bins=30, kde=True, color='blue')
plt.title('მიწისძვრის სიღრმის განაწილება')
plt.xlabel('სიღრმე (km)')
plt.ylabel('სიხშირე')
plt.show()

# %%
# ფიგურული დიაგრამა


import matplotlib.pyplot as plt

earthquakes_df_cleaned['Datetime'] = pd.to_datetime(
    earthquakes_df_cleaned['Date'].astype(str) + ' ' + earthquakes_df_cleaned['Time'],
    errors='coerce'
)

annual_earthquakes = earthquakes_df_cleaned.set_index('Datetime').resample('Y').size()

plt.figure(figsize=(12, 6))
plt.plot(annual_earthquakes.index.year, annual_earthquakes, marker='o', linestyle='-', color='b')
plt.title('მიწისძვრის წლიური სიხშირე დროთა განმავლობაში')
plt.xlabel('წელი')
plt.ylabel('რაოდენობა')
plt.grid(True)
plt.xticks(annual_earthquakes.index.year, rotation=45)
plt.tight_layout()
plt.show()
